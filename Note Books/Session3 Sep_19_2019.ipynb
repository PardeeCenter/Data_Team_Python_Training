# %% [markdown]
# <img src="https://pardee.du.edu/sites/default/files/PardeeCenterLogo_finalnew.png" />
# <p style="text-align: center;">yutang.xiong@du.edu </p>

# %%
import pandas as pd
import re
import time
import os

# %% [markdown]
# # Class Oject and its Attributes & Methods/Functions
#
# "Python is an “object-oriented programming language. <br>This means that almost all the code is implemented using a special construct called classes"<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;       -- found on a random page through google

# %%
class PardeeMember:
    # Attributes
    def __init__(self,name,gender):
        self.name=name
        self.gender=gender
        
        if gender=="male":
            self.gender2="he"
        elif gender=="female":
            self.gender2="she"
        
    # Methods
    def isboss(self):
        if self.name=="Yutang":
            return(f"Right, {self.gender2} is")
        else:
            return(f"Sorry, {self.gender2} is not")

# %%
d="He"
f"{d} does not know"
# Out:
# 'He does not know'

# %%
"He does not know"
# Out:
# 'He does not know'

# %%
a=PardeeMember("Yutang","male")
b=PardeeMember("Jon","male")
c=PardeeMember("Whitney","female")

# %%
a.name
# Out:
# 'Yutang'

# %%
a.gender
# Out:
# 'male'

# %%
# just an example, not necessarily true
a.isboss()
# Out:
# 'Right, he is'

# %%
# just an example, not necessarily true
c.isboss()
# Out:
# 'Sorry, she is not'

# %% [markdown]
# # Back to pandas dataframe practice
#
# "You can treat dataframe as a defined class, and its columns (series) as an inner class of dataframe." <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;       -- Yutang

# %%
dt=pd.read_excel("Sample Data/Diplometrics HoGS Education Info 20180706.xlsx")
dt.head(5)
# Out:
#                                 HoGS Education Table   Unnamed: 1  \
# 0  *Sorted by country, position title, and names ...          NaN
# 1                                                NaN          NaN
# 2                                           LeaderID      Country
# 3                                                  2  Afghanistan
# 4                                                  1  Afghanistan
#
#                     Unnamed: 2               Unnamed: 3   Unnamed: 4  \
# 0                          NaN                      NaN          NaN
# 1                          NaN                      NaN          NaN
# 2                        Title           Name_FirstLast  Degree_Type
# 3  Head of the Supreme Council      Mawlawi Abdul Kabir         None
# 4  Head of the Supreme Council  Mullah Mohammad Rabbani         None
#
#        Unnamed: 5              Unnamed: 6               Unnamed: 7  \
# 0             NaN                     NaN                      NaN
# ...

# %% [markdown]
# Columns headers (names) are in the 4th row, while in 0-indexed python, its associated with index 3

# %%
dt=pd.read_excel("Sample Data/Diplometrics HoGS Education Info 20180706.xlsx",skiprows=3)
# using skiprows=3 will also work
dt.head(5)
# Out:
#    LeaderID      Country                        Title  \
# 0         2  Afghanistan  Head of the Supreme Council
# 1         1  Afghanistan  Head of the Supreme Council
# 2         4  Afghanistan                    President
# 3         8  Afghanistan                    President
# 4         8  Afghanistan                    President
#
#             Name_FirstLast Degree_Type ForeignCountry Country_of_Institution  \
# 0      Mawlawi Abdul Kabir        None            NaN                    NaN
# 1  Mullah Mohammad Rabbani        None            NaN                    NaN
# 2        Abdul Rahim Hatef        None            NaN                    NaN
# 3             Ashraf Ghani        BACH            yes                Lebanon
# 4             Ashraf Ghani        MAST            yes                Lebanon
#
#   iso_Code_of_Institution                   Institution1 Institution2  \
# 0                     NaN                            NaN          NaN
# ...

# %% [markdown]
# # Exploring the data
# - Data info
# - str.strip()

# %%
# column types
dt.dtypes
# Out:
# LeaderID                    int64
# Country                    object
# Title                      object
# Name_FirstLast             object
# Degree_Type                object
# ForeignCountry             object
# Country_of_Institution     object
# iso_Code_of_Institution    object
# Institution1               object
# Institution2               object
# Institution3               object
# Institution4               object
# Institution5               object
# dtype: object

# %%
# size of the data
dt.shape
# Out:
# (3929, 13)

# %%
dt.head(1)
# Out:
#    LeaderID      Country                        Title       Name_FirstLast  \
# 0         2  Afghanistan  Head of the Supreme Council  Mawlawi Abdul Kabir
#
#   Degree_Type ForeignCountry Country_of_Institution iso_Code_of_Institution  \
# 0        None            NaN                    NaN                     NaN
#
#   Institution1 Institution2 Institution3 Institution4 Institution5
# 0          NaN          NaN          NaN          NaN          NaN

# %%
dt.Name_FirstLast[0]
# Out:
# 'Mawlawi Abdul Kabir'

# %%
type(dt.Name_FirstLast[0])
# Out:
# str

# %%
print('Yutang ')
print('Yutang')
'Yutang '=='Yutang'
# Out:
# Yutang
# Yutang
# False

# %%
# str.strip() default: Return a copy of the string with leading and trailing whitespace remove.
'Yutang '.strip()
# Out:
# 'Yutang'

# %%
'Yutang -'.strip("-")
# Out:
# 'Yutang '

# %%
for i in set(dt["Name_FirstLast"]):
    if i.strip()!=i:
        print(i.__repr__())
# Out:
# 'Joao Lourenco    '
# 'Willem-Alexander '
# 'Umberto II '

# %%
dt["Name_FirstLast_Cleaned"]=dt["Name_FirstLast"].apply(lambda x: x.strip())

# %%
dt.head(1)
# Out:
#    LeaderID      Country                        Title       Name_FirstLast  \
# 0         2  Afghanistan  Head of the Supreme Council  Mawlawi Abdul Kabir
#
#   Degree_Type ForeignCountry Country_of_Institution iso_Code_of_Institution  \
# 0        None            NaN                    NaN                     NaN
#
#   Institution1 Institution2 Institution3 Institution4 Institution5  \
# 0          NaN          NaN          NaN          NaN          NaN
#
#   Name_FirstLast_Cleaned
# 0    Mawlawi Abdul Kabir

# %%
# just to verify
for i in set(dt["Name_FirstLast_Cleaned"]):
    if i.strip()!=i:
        print(i.__repr__())

# %% [markdown]
# - Missing values
# - Slicing the data (Data subsetting)

# %%
dt.ForeignCountry.isna().sum()
# Out:
# 733

# %%
dt.ForeignCountry.notna().sum()
# Out:
# 3196

# %%
100*dt.ForeignCountry.isna().sum()/dt.shape[0]
# Out:
# 18.65614660218885

# %%
100*dt.ForeignCountry.notna().sum()/dt.shape[0]
# Out:
# 81.34385339781115

# %%
dt.Degree_Type.value_counts()
# Out:
# BACH       2085
# MAST        687
# Unknown     429
# PHD         324
# None        274
# JD           80
# MD           26
# OTHER        17
# MBA           7
# Name: Degree_Type, dtype: int64

# %%
dt[(dt["Country"]=="United States") & (dt["Title"]=="President")]
# Out:
#       LeaderID        Country      Title         Name_FirstLast Degree_Type  \
# 3720      2578  United States  President           Barack Obama        BACH
# 3721      2578  United States  President           Barack Obama          JD
# 3722      2576  United States  President           Bill Clinton        BACH
# 3723      2576  United States  President           Bill Clinton          JD
# 3724      2579  United States  President           Donald Trump        BACH
# 3725      2568  United States  President      Dwight Eisenhower        BACH
# 3726      2566  United States  President  Franklin D. Roosevelt        BACH
# 3727      2575  United States  President       George H.W. Bush        BACH
# 3728      2577  United States  President         George W. Bush        BACH
# 3729      2577  United States  President         George W. Bush         MBA
# 3730      2572  United States  President            Gerald Ford        BACH
# ...

# %%
dt[((dt["Country"]=="United States") & (dt["Title"]=="President"))  |  (dt["Country"]=="China") ]
# Out:
#       LeaderID        Country              Title         Name_FirstLast  \
# 625        442          China           Chairman             Mao Zedong
# 626        447          China   Defense Minister          Cao Gangchuan
# 627        449          China   Defense Minister          Chang Wanquan
# 628        446          China   Defense Minister            Chi Haotian
# 629        448          China   Defense Minister         Liang Guanglie
# 630        445          China   Defense Minister              Qin Jiwei
# 631        450          China   Defense Minister             Wei Fenghe
# 632        453          China   Foreign Minister            Li Zhaoxing
# 633        451          China   Foreign Minister            Qian Qichen
# 634        452          China   Foreign Minister           Tang Jiaxuan
# 635        455          China   Foreign Minister                Wang Yi
# 636        454          China   Foreign Minister            Yang Jiechi
# ...

# %%
dt[((dt["Country"]=="United States") |  (dt["Country"]=="China") ) &(dt["Title"]=="President")]
# Out:
#       LeaderID        Country      Title         Name_FirstLast Degree_Type  \
# 647        458          China  President              Hu Jintao        BACH
# 648        443          China  President            Hua Guofeng        None
# 649        457          China  President            Jiang Zemin        BACH
# 650        466          China  President            Li Xiannian        None
# 651        459          China  President             Xi Jinping        BACH
# 652        467          China  President          Yang Shangkun        BACH
# 653        467          China  President          Yang Shangkun        BACH
# 654        456          China  President            Zhao Ziyang        None
# 3720      2578  United States  President           Barack Obama        BACH
# 3721      2578  United States  President           Barack Obama          JD
# 3722      2576  United States  President           Bill Clinton        BACH
# ...
